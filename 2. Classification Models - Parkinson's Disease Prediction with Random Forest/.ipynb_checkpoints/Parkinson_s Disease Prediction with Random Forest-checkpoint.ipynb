# %% [markdown]
# # Parkinson's Disease Dataset
# Attribute Information:
# ----------------------
# Matrix column entries (attributes):
#
# name - ASCII subject name and recording number
#
# MDVP:Fo(Hz) - Average vocal fundamental frequency
#
# MDVP:Fhi(Hz) - Maximum vocal fundamental frequency
#
# MDVP:Flo(Hz) - Minimum vocal fundamental frequency
#
# MDVP:Jitter(%),MDVP:Jitter(Abs),MDVP:RAP,MDVP:PPQ,Jitter:DDP - Several measures of variation in fundamental frequency
#
# MDVP:Shimmer,
#
# MDVP:Shimmer(dB),
#
# Shimmer:APQ3,
#
# Shimmer:APQ5,
#
# MDVP:APQ,
#
# Shimmer:DDA - Several measures of variation in amplitude
#
# NHR,HNR - Two measures of ratio of noise to tonal components in the voice
#
# status - Health status of the subject (one) - Parkinson's, (zero) - healthy
#
# RPDE,D2 - Two nonlinear dynamical complexity measures
#
# DFA - Signal fractal scaling exponent
#
# spread1,spread2,PPE - Three nonlinear measures of fundamental frequency variation
#
#
# # 1. Importing Libraries for ML

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import RandomOverSampler
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
from sklearn.model_selection import cross_val_score

from sklearn.model_selection import train_test_split, GridSearchCV,RandomizedSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Importing Data

# %%
df = pd.read_csv('parkinsons.csv')
df.head(3)
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
#
# [3 rows x 24 columns]

# %% [markdown]
# # 3.  Data Cleaning
# 1. Finding the null values and handling them in proper way.
# 2. Drop uneccessay data columns.
# 3. Find outliers and remove them.

# %%
df.iloc[:3,:10]
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer
# 0           0.00007   0.00370   0.00554     0.01109       0.04374
# 1           0.00008   0.00465   0.00696     0.01394       0.06134
# 2           0.00009   0.00544   0.00781     0.01633       0.05233

# %%
df.iloc[:3,:14]
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374
# 1           0.00008   0.00465   0.00696     0.01394       0.06134
# 2           0.00009   0.00544   0.00781     0.01633       0.05233
#
#    MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ
# 0             0.426       0.02182       0.03130   0.02971
# 1             0.626       0.03134       0.04518   0.04368
# 2             0.482       0.02757       0.03858   0.03590

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# 25%            0.000020    0.001660    0.001860    0.004985      0.016505
# 50%            0.000030    0.002500    0.002690    0.007490      0.022970
# 75%            0.000060    0.003835    0.003955    0.011505      0.037885
# max            0.000260    0.021440    0.019580    0.064330      0.119080
#
#        MDVP:Shimmer(dB)  ...  Shimmer:DDA         NHR         HNR      status  \
# count        195.000000  ...   195.000000  195.000000  195.000000  195.000000
# mean           0.282251  ...     0.046993    0.024847   21.885974    0.753846
# std            0.194877  ...     0.030459    0.040418    4.425764    0.431878
# min            0.085000  ...     0.013640    0.000650    8.441000    0.000000
# 25%            0.148500  ...     0.024735    0.005925   19.198000    1.000000
# 50%            0.221000  ...     0.038360    0.011660   22.085000    1.000000
# 75%            0.350000  ...     0.060795    0.025640   25.075500    1.000000
# max            1.302000  ...     0.169420    0.314820   33.047000    1.000000
#
#              RPDE         DFA     spread1     spread2          D2         PPE
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     0.498536    0.718099   -5.684397    0.226510    2.381826    0.206552
# std      0.103942    0.055336    1.090208    0.083406    0.382799    0.090119
# min      0.256570    0.574282   -7.964984    0.006274    1.423287    0.044539
# 25%      0.421306    0.674758   -6.450096    0.174351    2.099125    0.137451
# 50%      0.495954    0.722254   -5.720868    0.218885    2.361532    0.194052
# 75%      0.587562    0.761881   -5.046192    0.279234    2.636456    0.252980
# max      0.685151    0.825288   -2.434031    0.450493    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
df.shape
# Out:
# (195, 24)

# %% [markdown]
# ## 3.1 Finding the null values

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# ## 3.2 Drop the "name" column which is unnecessary in predictive modelling.

# %%
df.drop(["name"], axis=1, inplace=True)

# %% [markdown]
# ## 3.3 Finding outliers and removing them.
#
# #### Create functions to
# - plot the outliers using boxplots and distplots
# - find outliers in skewed and normally distributed data.
# - remove outliers in skewed and normally distributed data.

# %%
# function to plot the distplot and boxplot for given dataframe and column
def plot_distribution(df, col):
    fig, ax =plt.subplots(1,2)
    plt.figure(figsize=(40,10))
    sns.distplot(df[col], ax=ax[0])  
    df.boxplot(column=col, ax=ax[1])
    plt.show()

# function to find outliers in normally distributed data
def find_outliers_normal(data, col):
    upper_bound = data[col].mean() + 3*data[col].std()
    lower_bound = data[col].mean() - 3*data[col].std()

    upper_outliers = len(data.loc[data[col]>upper_bound])
    lower_outliers = len(data.loc[data[col]>upper_bound])
    
    print("Outliers in '",col,"' Column")
    print("Upper Bound - ",upper_bound)
    print("Lower Bound - ",lower_bound)
    print("Number of Upper Outliers - ",upper_outliers)
    print("Number of Lower Outliers - ",lower_outliers)
    print("")

# function to find outliers in skewed data
def find_outliers_skewed(df, col):
    IQR = df[col].quantile(0.75)-df[col].quantile(0.25)
    
    upper_bound = df[col].quantile(0.75) + (IQR*1.5)
    lower_bound = df[col].quantile(0.25) - (IQR*1.5)
    
    upper_outliers = len(df.loc[df[col]>upper_bound])
    lower_outliers = len(df.loc[df[col]<lower_bound])
    
    
    print("Outliers in '",col,"' Column")
    print("Upper Bound - ",upper_bound)
    print("Lower Bound - ",lower_bound)
    print("Number of Upper Outliers - ",upper_outliers)
    print("Number of Lower Outliers - ",lower_outliers)
    print("")


    
# function to remove outliers from normally distributed data.
def remove_outliers_normal(df, col):
    df = df.copy(deep=True)
    upper_bound = df[col].mean() + 3*df[col].std()
    lower_bound = df[col].mean() - 3*df[col].std()
    
    df.loc[df[col]>=upper_bound, col] = upper_bound
    df.loc[df[col]<=lower_bound, col] = lower_bound
    
    return df


# function to remove outliers from skewed data.
def remove_outliers_skewed(df, col):
    IQR = df[col].quantile(0.75)-df[col].quantile(0.25)
    
    upper_bridge = df[col].quantile(0.75) + (IQR*1.5)
    lower_bridge = df[col].quantile(0.25) - (IQR*1.5)
    
    df.loc[df[col]>=upper_bridge, col] = upper_bridge
    df.loc[df[col]<=lower_bridge, col] = lower_bridge
    
    return df

# %%
features_list = list(df.columns)
features_list.remove("status")
print(features_list)
# Out:
# ['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)', 'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP', 'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5', 'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA', 'spread1', 'spread2', 'D2', 'PPE']

# %%
# plot distplot and boxplots for each column except "status column"
for i in features_list:
    plot_distribution(df, i)

# %%
# find out the outliers in data
for i in features_list:
    find_outliers_skewed(df, i)
# Out:
# Outliers in ' MDVP:Fo(Hz) ' Column
# Upper Bound -  280.5645
# Lower Bound -  19.7765
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Fhi(Hz) ' Column
# Upper Bound -  358.22
# Lower Bound -  0.8480000000000132
# Number of Upper Outliers -  11
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Flo(Hz) ' Column
# Upper Bound -  223.60975000000005
# Lower Bound -  0.6997499999999661
# Number of Upper Outliers -  9
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Jitter(%) ' Column
# Upper Bound -  0.0132225
# Lower Bound -  -0.0023975
# Number of Upper Outliers -  14
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Jitter(Abs) ' Column
# Upper Bound -  0.00011999999999999999
# Lower Bound -  -3.9999999999999996e-05
# Number of Upper Outliers -  7
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:RAP ' Column
# Upper Bound -  0.0070975
# Lower Bound -  -0.0016024999999999998
# Number of Upper Outliers -  14
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:PPQ ' Column
# Upper Bound -  0.0070975000000000005
# Lower Bound -  -0.0012825000000000002
# Number of Upper Outliers -  15
# Number of Lower Outliers -  0
#
# Outliers in ' Jitter:DDP ' Column
# Upper Bound -  0.021285000000000005
# Lower Bound -  -0.004795000000000002
# Number of Upper Outliers -  14
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Shimmer ' Column
# Upper Bound -  0.069955
# Lower Bound -  -0.015565000000000002
# Number of Upper Outliers -  8
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Shimmer(dB) ' Column
# Upper Bound -  0.65225
# Lower Bound -  -0.15374999999999997
# Number of Upper Outliers -  10
# Number of Lower Outliers -  0
#
# Outliers in ' Shimmer:APQ3 ' Column
# Upper Bound -  0.038294999999999996
# Lower Bound -  -0.009784999999999997
# Number of Upper Outliers -  6
# Number of Lower Outliers -  0
#
# Outliers in ' Shimmer:APQ5 ' Column
# Upper Bound -  0.041580000000000006
# Lower Bound -  -0.009620000000000002
# Number of Upper Outliers -  13
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:APQ ' Column
# Upper Bound -  0.05388
# Lower Bound -  -0.011400000000000002
# Number of Upper Outliers -  12
# Number of Lower Outliers -  0
#
# Outliers in ' Shimmer:DDA ' Column
# Upper Bound -  0.114885
# Lower Bound -  -0.029355
# Number of Upper Outliers -  6
# Number of Lower Outliers -  0
#
# Outliers in ' NHR ' Column
# Upper Bound -  0.0552125
# Lower Bound -  -0.023647500000000002
# Number of Upper Outliers -  19
# Number of Lower Outliers -  0
#
# Outliers in ' HNR ' Column
# Upper Bound -  33.891749999999995
# Lower Bound -  10.381750000000004
# Number of Upper Outliers -  0
# Number of Lower Outliers -  3
#
# Outliers in ' RPDE ' Column
# Upper Bound -  0.8369472499999999
# Lower Bound -  0.17192125000000005
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' DFA ' Column
# Upper Bound -  0.8925675
# Lower Bound -  0.5440715
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' spread1 ' Column
# Upper Bound -  -2.9403359999999985
# Lower Bound -  -8.555952000000001
# Number of Upper Outliers -  4
# Number of Lower Outliers -  0
#
# Outliers in ' spread2 ' Column
# Upper Bound -  0.43655924999999995
# Lower Bound -  0.017025250000000075
# Number of Upper Outliers -  1
# Number of Lower Outliers -  1
#
# Outliers in ' D2 ' Column
# Upper Bound -  3.44245175
# Lower Bound -  1.29312975
# Number of Upper Outliers -  1
# Number of Lower Outliers -  0
#
# Outliers in ' PPE ' Column
# Upper Bound -  0.42627349999999997
# Lower Bound -  -0.0358425
# Number of Upper Outliers -  5
# Number of Lower Outliers -  0

# %%
# remove the outliers from each column
for i in features_list:
    remove_outliers_skewed(df, i)

# %%
# See if their are outliers still exists in data
for i in features_list:
    find_outliers_skewed(df, i)
# Out:
# Outliers in ' MDVP:Fo(Hz) ' Column
# Upper Bound -  280.5645
# Lower Bound -  19.7765
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Fhi(Hz) ' Column
# Upper Bound -  358.22
# Lower Bound -  0.8480000000000132
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Flo(Hz) ' Column
# Upper Bound -  223.60975000000005
# Lower Bound -  0.6997499999999661
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Jitter(%) ' Column
# Upper Bound -  0.0132225
# Lower Bound -  -0.0023975
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Jitter(Abs) ' Column
# Upper Bound -  0.00011999999999999999
# Lower Bound -  -3.9999999999999996e-05
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:RAP ' Column
# Upper Bound -  0.0070975
# Lower Bound -  -0.0016024999999999998
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:PPQ ' Column
# Upper Bound -  0.0070975000000000005
# Lower Bound -  -0.0012825000000000002
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' Jitter:DDP ' Column
# Upper Bound -  0.021285000000000005
# Lower Bound -  -0.004795000000000002
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Shimmer ' Column
# Upper Bound -  0.069955
# Lower Bound -  -0.015565000000000002
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:Shimmer(dB) ' Column
# Upper Bound -  0.65225
# Lower Bound -  -0.15374999999999997
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' Shimmer:APQ3 ' Column
# Upper Bound -  0.038294999999999996
# Lower Bound -  -0.009784999999999997
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' Shimmer:APQ5 ' Column
# Upper Bound -  0.041580000000000006
# Lower Bound -  -0.009620000000000002
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' MDVP:APQ ' Column
# Upper Bound -  0.05388
# Lower Bound -  -0.011400000000000002
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' Shimmer:DDA ' Column
# Upper Bound -  0.114885
# Lower Bound -  -0.029355
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' NHR ' Column
# Upper Bound -  0.0552125
# Lower Bound -  -0.023647500000000002
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' HNR ' Column
# Upper Bound -  33.891749999999995
# Lower Bound -  10.381750000000004
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' RPDE ' Column
# Upper Bound -  0.8369472499999999
# Lower Bound -  0.17192125000000005
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' DFA ' Column
# Upper Bound -  0.8925675
# Lower Bound -  0.5440715
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' spread1 ' Column
# Upper Bound -  -2.9403359999999985
# Lower Bound -  -8.555952000000001
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' spread2 ' Column
# Upper Bound -  0.43655924999999995
# Lower Bound -  0.017025250000000075
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' D2 ' Column
# Upper Bound -  3.44245175
# Lower Bound -  1.29312975
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0
#
# Outliers in ' PPE ' Column
# Upper Bound -  0.42627349999999997
# Lower Bound -  -0.0358425
# Number of Upper Outliers -  0
# Number of Lower Outliers -  0

# %% [markdown]
# # 4. Feature Engineering
# ## 1. Selecting the features by using Heatmap of correlation, removing highly correlated features.
#    - Heatmap for plotting correlation matrix.
#    - Create function to remove highly correlated features

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
# function to find highly correlated features

def highly_correlated_columns(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
# highly correlated features
corr_features = highly_correlated_columns(df, 0.85)
corr_features
# Out:
# {'Jitter:DDP',
#  'MDVP:APQ',
#  'MDVP:Jitter(Abs)',
#  'MDVP:PPQ',
#  'MDVP:RAP',
#  'MDVP:Shimmer(dB)',
#  'PPE',
#  'Shimmer:APQ3',
#  'Shimmer:APQ5',
#  'Shimmer:DDA'}

# %%
# remove correlated features.
df.drop(corr_features, axis=1, inplace=True)

# %%
# See if their are other features which are highly correlated. 
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 4.2 Handling Imbalance data
#
# As we can see their is large imbalance in data, their are 48 records for negative class and 147 for positive class.

# %%
# split data into target and features
x = df.drop(["status"], axis=1)
y = df["status"]

# countplot() to see imbalance in data
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
# see how much records are their for each class
y.value_counts()
# Out:
# 1    147
# 0     48
# Name: status, dtype: int64

# %% [markdown]
# ###  Oversampling for imbalance dataset

# %%
over_sampler = RandomOverSampler()

x, y = over_sampler.fit_resample(x, y)

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
y.value_counts()
# Out:
# 0    147
# 1    147
# Name: status, dtype: int64

# %% [markdown]
# ## 4.3 Splitting Data into Features and Target

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=42, test_size=0.5)

# %% [markdown]
# # 5. Predictive Modelling
# ###  Finding the best `n_estimators` value for RandomForest Classifier
#
# Find the score for randomFOrest Classifier for each n_estimator value and see which n_estimator gives maximum value.

# %%
scores = []

for i in range(40,150,2):
    model = RandomForestClassifier(n_estimators=i, bootstrap=True,)
    
    model.fit(x_train,y_train)
    
    scores.append(model.score(x_test,y_test))

plt.plot(range(40,150,2), scores)

# %%
# find the n_estimator value for which score is highest
high_score_index = scores.index(max(scores))
estimators = np.arange(40,150,2)
n_est = estimators[high_score_index]

# %% [markdown]
# ### Define RandomForest Classifier

# %%
rf = RandomForestClassifier(n_estimators=n_est)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=44)

# %%
y_pred = rf.predict(x_test)

# %% [markdown]
# ### Evaluation of RandomForest Classifier

# %%
# Classification report for random forest classifier
cr = classification_report(y_test, y_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96        68
#            1       1.00      0.92      0.96        79
#
#     accuracy                           0.96       147
#    macro avg       0.96      0.96      0.96       147
# weighted avg       0.96      0.96      0.96       147

# %%
# Confusion matrix 
confusion_matrix(y_test, y_pred)
# Out:
# array([[68,  0],
#        [ 6, 73]])

# %%
# Score for model
rf.score(x_test, y_test)
# Out:
# 0.9591836734693877

# %% [markdown]
# # 6. Hyperparameter Tuning

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 1000, num = 5)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5,50,10)]

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,14]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,6,8]

# parameter dictionary for RandomizedSearchCV 
params = { 'max_features': max_features,
           'max_depth': max_depth,
           'min_samples_split': min_samples_split,
           'min_samples_leaf': min_samples_leaf,
           'criterion':['entropy','gini']}


rf_randomcv = RandomizedSearchCV(estimator=rf, param_distributions=params, n_iter=100, cv=5, verbose=2)

rf_randomcv.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=auto, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=auto, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=auto, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=auto, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=auto, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=log2, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=log2, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=log2, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=log2, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=log2, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=auto, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=auto, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=sqrt, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=sqrt, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=sqrt, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=sqrt, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=sqrt, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=log2, min_samples_leaf=6, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=8, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=log2, min_samples_leaf=6, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=log2, min_samples_leaf=6, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=log2, min_samples_leaf=6, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=log2, min_samples_leaf=6, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=40, max_features=log2, min_samples_leaf=6, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=sqrt, min_samples_leaf=6, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=10, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=45, max_features=sqrt, min_samples_leaf=2, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=50, max_features=auto, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=20, max_features=auto, min_samples_leaf=4, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, max_features=auto, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=sqrt, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=40, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=30, max_features=sqrt, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=25, max_features=auto, min_samples_leaf=8, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=20, max_features=sqrt, min_samples_leaf=6, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=auto, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, max_features=auto, min_samples_leaf=1, min_samples_split=14; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=50, max_features=log2, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=10, max_features=auto, min_samples_leaf=6, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=8, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=8, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=8, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=8, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=8, min_samples_split=14; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=log2, min_samples_leaf=6, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=log2, min_samples_leaf=6, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=log2, min_samples_leaf=6, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=log2, min_samples_leaf=6, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=45, max_features=log2, min_samples_leaf=6, min_samples_split=2; total time=   0.1s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(n_estimators=44),
#                    n_iter=100,
#                    param_distributions={'criterion': ['entropy', 'gini'],
#                                         'max_depth': [5, 10, 15, 20, 25, 30, 35,
#                                                       40, 45, 50],
#                                         'max_features': ['auto', 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': [1, 2, 4, 6, 8],
#                                         'min_samples_split': [2, 5, 10, 14]},
#                    verbose=2)

# %%
y_prediction  = rf_randomcv.predict(x_test)

# %%
# Classification report for random forest classifier after hyperparamter tuning
cr = classification_report(y_test, y_prediction)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94        68
#            1       1.00      0.89      0.94        79
#
#     accuracy                           0.94       147
#    macro avg       0.94      0.94      0.94       147
# weighted avg       0.95      0.94      0.94       147

# %%
# Confusion matrix  after hyperparamter tuning
confusion_matrix(y_test, y_prediction)
# Out:
# array([[68,  0],
#        [ 9, 70]])

# %%
# Score for model after hyperparamter tuning
rf_randomcv.score(x_test, y_test)
# Out:
# 0.9387755102040817

# %%
# Best hyperparameter values  after hyperparamter tuning
rf_randomcv.best_params_
# Out:
# {'min_samples_split': 5,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 40,
#  'criterion': 'gini'}

# %% [markdown]
# # Thank you !!!
